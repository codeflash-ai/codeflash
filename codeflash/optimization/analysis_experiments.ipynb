# %%
from metrics_analysis import *
DATABASE_URI = "postgresql://cf_admin:ta3Fyxe62u9vJ4jX7CRKqZkgQLY8E5@codeflash-pgsql-db-prod.postgres.database.azure.com:5432/postgres"
df = load_data(DATABASE_URI)

df = process_column_pairs(df, "metadata")
df = process_column_pairs(df, "test_framework")
df = process_column_pairs(df, "generated_test")

# %%
all_candidates_time_saved = df.apply(
        lambda row: row["original_runtime"]
        - min(
            runtime for opt_id, runtime in row["optimized_runtime"].items() if row["is_correct"].get(opt_id)
        )
        if row["optimized_runtime"] and row["is_correct"]
        else None,
        axis=1,
    ).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 all_candidates_time_saved = df.apply(
#       2         lambda row: row["original_runtime"]
#       3         - min(
#       4             runtime for opt_id, runtime in row["optimized_runtime"].items() if row["is_correct"].get(opt_id)
#       5         )
#       6         if row["optimized_runtime"] and row["is_correct"]
#       7         else None,
#       8         axis=1,
#       9     ).mean()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[2], line 3, in <lambda>(row)
#       1 all_candidates_time_saved = df.apply(
#       2         lambda row: row["original_runtime"]
# ----> 3         - min(
#       4             runtime for opt_id, runtime in row["optimized_runtime"].items() if row["is_correct"].get(opt_id)
#       5         )
#       6         if row["optimized_runtime"] and row["is_correct"]
#       7         else None,
#       8         axis=1,
#       9     ).mean()
#
# ValueError: min() iterable argument is empty

# %%
df
# Out:
#                                 trace_id  \
# 0   0737f6d0-2837-4e89-9329-b874dd85EXP1
# 1   c8d3c1f5-dc36-4662-93f0-89b1a728EXP1
# 2   004b83d1-d244-4574-a686-75528771EXP0
# 3   f12774fd-abde-4a96-a956-bb497851EXP0
# 4   f9f80c75-23a2-4da7-b7cb-46b55e98EXP0
# 5   e8b0b6c8-be2d-4187-bbab-a452ea2cEXP0
# 6   675984d2-40c5-44e7-89f6-0ef88958EXP1
# 7   87fae3ca-9e3b-4741-9cc2-7a8928d7EXP0
# 8   87fae3ca-9e3b-4741-9cc2-7a8928d7EXP1
# 9   d0fe1471-f997-41e6-a7d5-e2bf7335EXP0
# 10  d0fe1471-f997-41e6-a7d5-e2bf7335EXP1
# 11  07aaa994-f3c1-45bd-8291-8f5d0449EXP0
# 12  07aaa994-f3c1-45bd-8291-8f5d0449EXP1
# 13  52ecc4df-ebc3-4eb9-9ca5-6ab4649dEXP0
# 14  52ecc4df-ebc3-4eb9-9ca5-6ab4649dEXP1
# 15  19d849fc-eed9-4475-b9bc-1a290181EXP0
# 16  19d849fc-eed9-4475-b9bc-1a290181EXP1
# 17  5754ebe4-f66f-424c-95a9-10d9f464EXP0
# 18  5754ebe4-f66f-424c-95a9-10d9f464EXP1
# 19  004b83d1-d244-4574-a686-75528771EXP1
# 20  f9f80c75-23a2-4da7-b7cb-46b55e98EXP1
# 21  169e3ad1-83b3-4767-b5bc-0d28042dEXP0
# 22  169e3ad1-83b3-4767-b5bc-0d28042dEXP1
# 23  f12774fd-abde-4a96-a956-bb497851EXP1
# 24  e8b0b6c8-be2d-4187-bbab-a452ea2cEXP1
# 25  dcf32584-d3c7-4596-8586-f851c86aEXP1
# 26  dcf32584-d3c7-4596-8586-f851c86aEXP0
# 27  0737f6d0-2837-4e89-9329-b874dd85EXP0
# 28  e6f50399-d2f6-4091-90e7-ccaa973cEXP0
# 29  e6f50399-d2f6-4091-90e7-ccaa973cEXP1
# 30  7a02881b-1a2b-4bf9-8ed3-46a44c11EXP0
# 31  7a02881b-1a2b-4bf9-8ed3-46a44c11EXP1
# 32  73242db2-ba0f-48f4-8609-9006feb3EXP0
# 33  73242db2-ba0f-48f4-8609-9006feb3EXP1
# 34  543270b0-9c95-49d2-99d2-c3325728EXP1
# 35  543270b0-9c95-49d2-99d2-c3325728EXP0
# 36  cdd5326e-ade3-44a8-b060-c679e2c5EXP0
# 37  cdd5326e-ade3-44a8-b060-c679e2c5EXP1
# 38  a636440e-20eb-446e-829e-3276ef43EXP0
# 39  a636440e-20eb-446e-829e-3276ef43EXP1
# 40  c8d3c1f5-dc36-4662-93f0-89b1a728EXP0
#
#                                         original_code  \
# 0   \ndef problem_p02847(input_data):\n    def mai...
# 1   \ndef problem_p03196(input_data):\n    n, p = ...
# 2   \ndef problem_p03861(input_data):\n    import ...
# 3   \ndef problem_p02910(input_data):\n    s = eva...
# 4   \ndef problem_p03965(input_data):\n    # len(s...
# 5   \ndef problem_p02553(input_data):\n    import ...
# 6   \ndef problem_p02818(input_data):\n    a, b, k...
# 7   \ndef problem_p02765(input_data):\n    N, R = ...
# 8   \ndef problem_p02765(input_data):\n    N, R = ...
# 9   \ndef problem_p03778(input_data):\n    W, a, b...
# 10  \ndef problem_p03778(input_data):\n    W, a, b...
# 11  \ndef problem_p03729(input_data):\n    A, B, C...
# 12  \ndef problem_p03729(input_data):\n    A, B, C...
# 13  \ndef problem_p03544(input_data):\n    N = int...
# 14  \ndef problem_p03544(input_data):\n    N = int...
# 15  \ndef problem_p02960(input_data):\n    S = eva...
# 16  \ndef problem_p02960(input_data):\n    S = eva...
# 17  \ndef problem_p02690(input_data):\n    X = int...
# 18  \ndef problem_p02690(input_data):\n    X = int...
# 19  \ndef problem_p03861(input_data):\n    import ...
# 20  \ndef problem_p03965(input_data):\n    # len(s...
# 21  \ndef problem_p03149(input_data):\n    s = eva...
# 22  \ndef problem_p03149(input_data):\n    s = eva...
# 23  \ndef problem_p02910(input_data):\n    s = eva...
# 24  \ndef problem_p02553(input_data):\n    import ...
# 25  \ndef problem_p03024(input_data):\n    S = eva...
# 26  \ndef problem_p03024(input_data):\n    S = eva...
# 27  \ndef problem_p02847(input_data):\n    def mai...
# 28  \ndef problem_p02667(input_data):\n    t = eva...
# 29  \ndef problem_p02667(input_data):\n    t = eva...
# 30  \ndef problem_p03643(input_data):\n    N = eva...
# 31  \ndef problem_p03643(input_data):\n    N = eva...
# 32  \ndef problem_p02970(input_data):\n    import ...
# 33  \ndef problem_p02970(input_data):\n    import ...
# 34  \ndef problem_p02957(input_data):\n    import ...
# 35  \ndef problem_p02957(input_data):\n    import ...
# 36  \ndef problem_p02927(input_data):\n    M, D = ...
# 37  \ndef problem_p02927(input_data):\n    M, D = ...
# 38  \ndef problem_p03547(input_data):\n    #!/usr/...
# 39  \ndef problem_p03547(input_data):\n    #!/usr/...
# 40  \ndef problem_p03196(input_data):\n    n, p = ...
#
#                                     optimizations_raw  \
# 0   {'00db208c-b4df-4ac0-bf2c-4448f0c18897': 'def ...
# 1   {'426916b1-b122-44a7-aae3-c806b81887bd': 'def ...
# 2   {'0a631960-6c33-4de4-8d38-b31e888918c7': 'def ...
# 3   {'00f11305-5a9b-43cf-9d97-720b0a465d52': '
# def...
# 4   {'000711ac-1663-496b-837b-946040155a9c': '
# def...
# 5   {'04e41d16-15f6-4341-a976-f420ed3180a6': 'def ...
# 6   {'0ac2d5fc-7315-4ca1-af84-1a7d65cd93a6': 'def ...
# 7   {'21645d50-d094-47d5-9a16-9163d90ee040': '
# def...
# 8   {'3b74021f-df2a-43c1-a98c-c53c62c152b4': 'def ...
# 9   {'093d324b-76aa-4ad7-ab24-a4d10341d635': 'def ...
# 10  {'0ac7066f-a5cd-417c-8121-0614754e6b0a': 'def ...
# 11  {'4bf3dbec-6785-4cde-854b-f6331cba2a76': 'def ...
# 12  {'0e07a41c-8928-4d69-a0ba-33c8c2a29368': 'def ...
# 13  {'0717e2a6-a0ff-4e2b-950e-3e89cdf1a943': 'def ...
# 14  {'2bdd685e-9076-4c06-af56-ed592ec2add9': 'def ...
# 15  {'0e834ccc-68e2-4ba2-929e-0362e7288322': 'def ...
# 16  {'0ca93779-ea4a-48a9-9437-600334e2b5bb': 'def ...
# 17  {'0c30fb73-0bac-475d-b78b-c6c099bc12ad': 'def ...
# 18  {'10eb6770-047a-4f60-b9ad-0d2688bab93b': 'def ...
# 19  {'0aafef05-c468-48e0-a795-986763cf6b7c': 'def ...
# 20  {'04068a66-840b-4ddb-a8c7-289be75266e4': 'def ...
# 21  {'226ed33b-0ca7-4e7c-8384-b8dc96b1b1f4': 'def ...
# 22  {'09301913-2eb2-40b2-8b51-49566e08ced7': 'from...
# 23  {'0f86c075-6684-4c13-92cf-3166941c5c4c': 'def ...
# 24  {'0485cc8e-6ebd-4c81-9aed-61687af1c8ed': 'def ...
# 25  {'1692b2dd-d865-466f-97d0-cd4859ea585d': 'def ...
# 26  {'1b3fcdb9-bdf2-419b-bf10-b4482dc75d8b': 'def ...
# 27  {'0257e7cf-b4a8-4771-bb02-6e4963fa9811': '
# def...
# 28  {'7ce6c3ed-4d5c-4a93-8f13-607d4fc92e03': 'def ...
# 29  {'349055c3-aec3-4872-8ad0-67965b7fcca8': 'def ...
# 30  {'3af102b2-e9a4-45d1-b6a4-da7d4cf77bf0': 'def ...
# 31  {'2442d889-079f-412a-b19c-e6b7c8cc77b2': 'def ...
# 32  {'06c81727-979e-4749-a61e-eeff019418b2': 'def ...
# 33  {'164e2619-d401-448d-8ef2-f17d6afac3b9': 'impo...
# 34  {'62e3b5fb-cf2b-4f76-8744-ccfd527ffd3f': 'def ...
# 35  {'45485c8f-f983-460a-9f33-2bb65c902530': 'def ...
# 36  {'06b34dc8-32bf-4e73-b344-4bc0962ba53e': 'def ...
# 37  {'114cd4d1-089f-482f-9cd1-994e06230713': 'def ...
# 38  {'248e3790-6c3e-4aa8-b33f-83f774e3aa1e': 'def ...
# 39  {'2db980c5-9316-418d-abcb-99587afe301c': 'def ...
# 40  {'083209b7-561e-4272-80c5-ecce1708dc67': '
# def...
#
#                                    optimizations_post  \
# 0   {'00db208c-b4df-4ac0-bf2c-4448f0c18897': 'def ...
# 1   {'426916b1-b122-44a7-aae3-c806b81887bd': 'def ...
# 2   {'0a631960-6c33-4de4-8d38-b31e888918c7': 'def ...
# 3   {'00f11305-5a9b-43cf-9d97-720b0a465d52': '
# def...
# 4   {'000711ac-1663-496b-837b-946040155a9c': '
# def...
# 5   {'04e41d16-15f6-4341-a976-f420ed3180a6': 'def ...
# 6   {'0ac2d5fc-7315-4ca1-af84-1a7d65cd93a6': 'def ...
# 7   {'21645d50-d094-47d5-9a16-9163d90ee040': '
# def...
# 8   {'3b74021f-df2a-43c1-a98c-c53c62c152b4': 'def ...
# 9   {'093d324b-76aa-4ad7-ab24-a4d10341d635': 'def ...
# 10  {'0ac7066f-a5cd-417c-8121-0614754e6b0a': 'def ...
# 11  {'4bf3dbec-6785-4cde-854b-f6331cba2a76': 'def ...
# 12  {'0e07a41c-8928-4d69-a0ba-33c8c2a29368': 'def ...
# 13  {'0717e2a6-a0ff-4e2b-950e-3e89cdf1a943': 'def ...
# 14  {'2bdd685e-9076-4c06-af56-ed592ec2add9': 'def ...
# 15  {'0e834ccc-68e2-4ba2-929e-0362e7288322': 'def ...
# 16  {'0ca93779-ea4a-48a9-9437-600334e2b5bb': 'def ...
# 17  {'0c30fb73-0bac-475d-b78b-c6c099bc12ad': 'def ...
# 18  {'10eb6770-047a-4f60-b9ad-0d2688bab93b': 'def ...
# 19  {'3207699e-1363-4157-b61b-76c3522e7723': 'def ...
# 20  {'04068a66-840b-4ddb-a8c7-289be75266e4': 'def ...
# 21  {'226ed33b-0ca7-4e7c-8384-b8dc96b1b1f4': 'def ...
# 22  {'09301913-2eb2-40b2-8b51-49566e08ced7': 'from...
# 23  {'0f86c075-6684-4c13-92cf-3166941c5c4c': 'def ...
# 24  {'0485cc8e-6ebd-4c81-9aed-61687af1c8ed': 'def ...
# 25  {'1692b2dd-d865-466f-97d0-cd4859ea585d': 'def ...
# 26  {'1b3fcdb9-bdf2-419b-bf10-b4482dc75d8b': 'def ...
# 27  {'0257e7cf-b4a8-4771-bb02-6e4963fa9811': '
# def...
# 28  {'7ce6c3ed-4d5c-4a93-8f13-607d4fc92e03': 'def ...
# 29  {'349055c3-aec3-4872-8ad0-67965b7fcca8': 'def ...
# 30  {'3af102b2-e9a4-45d1-b6a4-da7d4cf77bf0': 'def ...
# 31  {'44cb2a7c-e9f1-49e0-b644-2591ff3f91f1': 'def ...
# 32  {'06c81727-979e-4749-a61e-eeff019418b2': 'def ...
# 33  {'164e2619-d401-448d-8ef2-f17d6afac3b9': 'impo...
# 34  {'62e3b5fb-cf2b-4f76-8744-ccfd527ffd3f': 'def ...
# 35  {'45485c8f-f983-460a-9f33-2bb65c902530': 'def ...
# 36  {'06b34dc8-32bf-4e73-b344-4bc0962ba53e': 'def ...
# 37  {'114cd4d1-089f-482f-9cd1-994e06230713': 'def ...
# 38  {'7fb2383c-34db-44bf-890e-16c3f4e5c4bd': 'def ...
# 39  {'2db980c5-9316-418d-abcb-99587afe301c': 'def ...
# 40  {'083209b7-561e-4272-80c5-ecce1708dc67': '
# def...
#
#                                     explanations_post  \
# 0   {'00db208c-b4df-4ac0-bf2c-4448f0c18897': 'The ...
# 1   {'426916b1-b122-44a7-aae3-c806b81887bd': 'The ...
# 2   {'0a631960-6c33-4de4-8d38-b31e888918c7': 'Here...
# 3   {'00f11305-5a9b-43cf-9d97-720b0a465d52': 'Your...
# 4   {'000711ac-1663-496b-837b-946040155a9c': 'Here...
# 5   {'04e41d16-15f6-4341-a976-f420ed3180a6': 'Here...
# 6   {'0ac2d5fc-7315-4ca1-af84-1a7d65cd93a6': 'In t...
# 7   {'21645d50-d094-47d5-9a16-9163d90ee040': 'The ...
# 8   {'3b74021f-df2a-43c1-a98c-c53c62c152b4': 'As t...
# 9   {'093d324b-76aa-4ad7-ab24-a4d10341d635': 'The ...
# 10  {'0ac7066f-a5cd-417c-8121-0614754e6b0a': 'The ...
# 11  {'4bf3dbec-6785-4cde-854b-f6331cba2a76': 'The ...
# 12  {'0e07a41c-8928-4d69-a0ba-33c8c2a29368': 'In t...
# 13  {'0717e2a6-a0ff-4e2b-950e-3e89cdf1a943': 'This...
# 14  {'2bdd685e-9076-4c06-af56-ed592ec2add9': 'The ...
# 15  {'0e834ccc-68e2-4ba2-929e-0362e7288322': 'The ...
# 16  {'0ca93779-ea4a-48a9-9437-600334e2b5bb': 'The ...
# 17  {'0c30fb73-0bac-475d-b78b-c6c099bc12ad': 'The ...
# 18  {'10eb6770-047a-4f60-b9ad-0d2688bab93b': 'I've...
# 19  {'3207699e-1363-4157-b61b-76c3522e7723': 'I've...
# 20  {'04068a66-840b-4ddb-a8c7-289be75266e4': 'The ...
# 21  {'226ed33b-0ca7-4e7c-8384-b8dc96b1b1f4': 'To o...
# 22  {'09301913-2eb2-40b2-8b51-49566e08ced7': 'The ...
# 23  {'0f86c075-6684-4c13-92cf-3166941c5c4c': 'The ...
# 24  {'0485cc8e-6ebd-4c81-9aed-61687af1c8ed': 'Revi...
# 25  {'1692b2dd-d865-466f-97d0-cd4859ea585d': 'In t...
# 26  {'1b3fcdb9-bdf2-419b-bf10-b4482dc75d8b': 'Your...
# 27  {'0257e7cf-b4a8-4771-bb02-6e4963fa9811': 'The ...
# 28  {'7ce6c3ed-4d5c-4a93-8f13-607d4fc92e03': 'The ...
# 29  {'349055c3-aec3-4872-8ad0-67965b7fcca8': 'In t...
# 30  {'3af102b2-e9a4-45d1-b6a4-da7d4cf77bf0': 'The ...
# 31  {'44cb2a7c-e9f1-49e0-b644-2591ff3f91f1': 'I've...
# 32  {'06c81727-979e-4749-a61e-eeff019418b2': 'Your...
# 33  {'164e2619-d401-448d-8ef2-f17d6afac3b9': 'The ...
# 34  {'62e3b5fb-cf2b-4f76-8744-ccfd527ffd3f': 'I've...
# 35  {'45485c8f-f983-460a-9f33-2bb65c902530': 'The ...
# 36  {'06b34dc8-32bf-4e73-b344-4bc0962ba53e': 'The ...
# 37  {'114cd4d1-089f-482f-9cd1-994e06230713': 'I've...
# 38  {'7fb2383c-34db-44bf-890e-16c3f4e5c4bd': 'The ...
# 39  {'2db980c5-9316-418d-abcb-99587afe301c': 'I've...
# 40  {'083209b7-561e-4272-80c5-ecce1708dc67': 'Here...
#
#                                         speedup_ratio  original_runtime  \
# 0   {'00db208c-b4df-4ac0-bf2c-4448f0c18897': None,...           14625.0
# 1                                                None               NaN
# 2   {'0a631960-6c33-4de4-8d38-b31e888918c7': 0.014...           60039.0
# 3   {'00f11305-5a9b-43cf-9d97-720b0a465d52': None,...         1029209.0
# 4   {'000711ac-1663-496b-837b-946040155a9c': -0.11...          244251.0
# 5   {'04e41d16-15f6-4341-a976-f420ed3180a6': 1774....        81020500.0
# 6   {'0ac2d5fc-7315-4ca1-af84-1a7d65cd93a6': 0.061...           34711.0
# 7   {'21645d50-d094-47d5-9a16-9163d90ee040': 0.257...            8333.0
# 8   {'3b74021f-df2a-43c1-a98c-c53c62c152b4': -0.03...            8333.0
# 9   {'093d324b-76aa-4ad7-ab24-a4d10341d635': 2284....        84961335.0
# 10  {'0ac7066f-a5cd-417c-8121-0614754e6b0a': 2321....        84961335.0
# 11  {'4bf3dbec-6785-4cde-854b-f6331cba2a76': None,...           19625.0
# 12  {'0e07a41c-8928-4d69-a0ba-33c8c2a29368': None,...           19625.0
# 13  {'0717e2a6-a0ff-4e2b-950e-3e89cdf1a943': None,...       193978374.0
# 14  {'2bdd685e-9076-4c06-af56-ed592ec2add9': None,...       193978374.0
# 15  {'0e834ccc-68e2-4ba2-929e-0362e7288322': -0.22...         1018957.0
# 16  {'0ca93779-ea4a-48a9-9437-600334e2b5bb': -0.01...         1018957.0
# 17  {'0c30fb73-0bac-475d-b78b-c6c099bc12ad': 1.474...       164707456.0
# 18  {'10eb6770-047a-4f60-b9ad-0d2688bab93b': 163.9...       164707456.0
# 19  {'3207699e-1363-4157-b61b-76c3522e7723': 0.222...           60039.0
# 20  {'0d174514-651a-4407-b89f-119639914ac0': -0.02...          244251.0
# 21  {'226ed33b-0ca7-4e7c-8384-b8dc96b1b1f4': None,...          241291.0
# 22  {'09301913-2eb2-40b2-8b51-49566e08ced7': None,...          241291.0
# 23  {'0f86c075-6684-4c13-92cf-3166941c5c4c': None,...         1029209.0
# 24  {'0485cc8e-6ebd-4c81-9aed-61687af1c8ed': None,...        81020500.0
# 25  {'1692b2dd-d865-466f-97d0-cd4859ea585d': None,...          202419.0
# 26  {'1b3fcdb9-bdf2-419b-bf10-b4482dc75d8b': None,...          202419.0
# 27  {'0257e7cf-b4a8-4771-bb02-6e4963fa9811': None,...           14625.0
# 28  {'7ce6c3ed-4d5c-4a93-8f13-607d4fc92e03': None,...        13320210.0
# 29  {'349055c3-aec3-4872-8ad0-67965b7fcca8': None,...        13320210.0
# 30  {'3af102b2-e9a4-45d1-b6a4-da7d4cf77bf0': None,...           46792.0
# 31  {'44cb2a7c-e9f1-49e0-b644-2591ff3f91f1': None,...           46792.0
# 32  {'06c81727-979e-4749-a61e-eeff019418b2': None,...        35739709.0
# 33  {'164e2619-d401-448d-8ef2-f17d6afac3b9': 1156....        35739709.0
# 34  {'62e3b5fb-cf2b-4f76-8744-ccfd527ffd3f': None,...          768040.0
# 35  {'45485c8f-f983-460a-9f33-2bb65c902530': None,...          768040.0
# 36  {'06b34dc8-32bf-4e73-b344-4bc0962ba53e': None,...       250921544.0
# 37  {'114cd4d1-089f-482f-9cd1-994e06230713': 0.107...       250921544.0
# 38  {'7fb2383c-34db-44bf-890e-16c3f4e5c4bd': None,...           14665.0
# 39  {'2db980c5-9316-418d-abcb-99587afe301c': -0.02...           14665.0
# 40                                               None               NaN
#
#                                     optimized_runtime  \
# 0   {'00db208c-b4df-4ac0-bf2c-4448f0c18897': None,...
# 1                                                None
# 2   {'0a631960-6c33-4de4-8d38-b31e888918c7': 59209...
# 3   {'00f11305-5a9b-43cf-9d97-720b0a465d52': None,...
# 4   {'000711ac-1663-496b-837b-946040155a9c': 27683...
# 5   {'04e41d16-15f6-4341-a976-f420ed3180a6': 45627...
# 6   {'0ac2d5fc-7315-4ca1-af84-1a7d65cd93a6': 32706...
# 7   {'21645d50-d094-47d5-9a16-9163d90ee040': 6625,...
# 8   {'3b74021f-df2a-43c1-a98c-c53c62c152b4': 8624,...
# 9   {'093d324b-76aa-4ad7-ab24-a4d10341d635': 37170...
# 10  {'0ac7066f-a5cd-417c-8121-0614754e6b0a': 36581...
# 11  {'4bf3dbec-6785-4cde-854b-f6331cba2a76': None,...
# 12  {'0e07a41c-8928-4d69-a0ba-33c8c2a29368': None,...
# 13  {'0717e2a6-a0ff-4e2b-950e-3e89cdf1a943': None,...
# 14  {'2bdd685e-9076-4c06-af56-ed592ec2add9': None,...
# 15  {'0e834ccc-68e2-4ba2-929e-0362e7288322': 13076...
# 16  {'0ca93779-ea4a-48a9-9437-600334e2b5bb': 10304...
# 17  {'0c30fb73-0bac-475d-b78b-c6c099bc12ad': 66554...
# 18  {'10eb6770-047a-4f60-b9ad-0d2688bab93b': 99866...
# 19  {'3207699e-1363-4157-b61b-76c3522e7723': 49127...
# 20  {'0d174514-651a-4407-b89f-119639914ac0': 25029...
# 21  {'226ed33b-0ca7-4e7c-8384-b8dc96b1b1f4': None,...
# 22  {'09301913-2eb2-40b2-8b51-49566e08ced7': None,...
# 23  {'0f86c075-6684-4c13-92cf-3166941c5c4c': None,...
# 24  {'0485cc8e-6ebd-4c81-9aed-61687af1c8ed': None,...
# 25  {'1692b2dd-d865-466f-97d0-cd4859ea585d': None,...
# 26  {'1b3fcdb9-bdf2-419b-bf10-b4482dc75d8b': None,...
# 27  {'0257e7cf-b4a8-4771-bb02-6e4963fa9811': None,...
# 28  {'7ce6c3ed-4d5c-4a93-8f13-607d4fc92e03': None,...
# 29  {'349055c3-aec3-4872-8ad0-67965b7fcca8': None,...
# 30  {'3af102b2-e9a4-45d1-b6a4-da7d4cf77bf0': None,...
# 31  {'44cb2a7c-e9f1-49e0-b644-2591ff3f91f1': None,...
# 32  {'06c81727-979e-4749-a61e-eeff019418b2': None,...
# 33  {'164e2619-d401-448d-8ef2-f17d6afac3b9': 30876...
# 34  {'62e3b5fb-cf2b-4f76-8744-ccfd527ffd3f': None,...
# 35  {'45485c8f-f983-460a-9f33-2bb65c902530': None,...
# 36  {'06b34dc8-32bf-4e73-b344-4bc0962ba53e': None,...
# 37  {'114cd4d1-089f-482f-9cd1-994e06230713': 22653...
# 38  {'7fb2383c-34db-44bf-890e-16c3f4e5c4bd': None,...
# 39  {'2db980c5-9316-418d-abcb-99587afe301c': 14997...
# 40                                               None
#
#                                            is_correct  \
# 0   {'00db208c-b4df-4ac0-bf2c-4448f0c18897': False...
# 1                                                None
# 2   {'0a631960-6c33-4de4-8d38-b31e888918c7': True,...
# 3   {'00f11305-5a9b-43cf-9d97-720b0a465d52': False...
# 4   {'000711ac-1663-496b-837b-946040155a9c': True,...
# 5   {'04e41d16-15f6-4341-a976-f420ed3180a6': True,...
# 6   {'0ac2d5fc-7315-4ca1-af84-1a7d65cd93a6': True,...
# 7   {'21645d50-d094-47d5-9a16-9163d90ee040': True,...
# 8   {'3b74021f-df2a-43c1-a98c-c53c62c152b4': True,...
# 9   {'093d324b-76aa-4ad7-ab24-a4d10341d635': True,...
# 10  {'0ac7066f-a5cd-417c-8121-0614754e6b0a': True,...
# 11  {'4bf3dbec-6785-4cde-854b-f6331cba2a76': False...
# 12  {'0e07a41c-8928-4d69-a0ba-33c8c2a29368': False...
# 13  {'0717e2a6-a0ff-4e2b-950e-3e89cdf1a943': False...
# 14  {'2bdd685e-9076-4c06-af56-ed592ec2add9': False...
# 15  {'0e834ccc-68e2-4ba2-929e-0362e7288322': True,...
# 16  {'0ca93779-ea4a-48a9-9437-600334e2b5bb': True,...
# 17  {'0c30fb73-0bac-475d-b78b-c6c099bc12ad': True,...
# 18  {'10eb6770-047a-4f60-b9ad-0d2688bab93b': True,...
# 19  {'3207699e-1363-4157-b61b-76c3522e7723': True,...
# 20  {'0d174514-651a-4407-b89f-119639914ac0': True,...
# 21  {'226ed33b-0ca7-4e7c-8384-b8dc96b1b1f4': False...
# 22  {'09301913-2eb2-40b2-8b51-49566e08ced7': False...
# 23  {'0f86c075-6684-4c13-92cf-3166941c5c4c': False...
# 24  {'0485cc8e-6ebd-4c81-9aed-61687af1c8ed': False...
# 25  {'1692b2dd-d865-466f-97d0-cd4859ea585d': False...
# 26  {'1b3fcdb9-bdf2-419b-bf10-b4482dc75d8b': False...
# 27  {'0257e7cf-b4a8-4771-bb02-6e4963fa9811': False...
# 28  {'7ce6c3ed-4d5c-4a93-8f13-607d4fc92e03': False...
# 29  {'349055c3-aec3-4872-8ad0-67965b7fcca8': False...
# 30  {'3af102b2-e9a4-45d1-b6a4-da7d4cf77bf0': False...
# 31  {'44cb2a7c-e9f1-49e0-b644-2591ff3f91f1': False...
# 32  {'06c81727-979e-4749-a61e-eeff019418b2': False...
# 33  {'164e2619-d401-448d-8ef2-f17d6afac3b9': True,...
# 34  {'62e3b5fb-cf2b-4f76-8744-ccfd527ffd3f': False...
# 35  {'45485c8f-f983-460a-9f33-2bb65c902530': False...
# 36  {'06b34dc8-32bf-4e73-b344-4bc0962ba53e': False...
# 37  {'114cd4d1-089f-482f-9cd1-994e06230713': True,...
# 38  {'7fb2383c-34db-44bf-890e-16c3f4e5c4bd': False...
# 39  {'2db980c5-9316-418d-abcb-99587afe301c': True,...
# 40                                               None
#
#                                        generated_test test_framework  \
# 0   [# imports\nimport pytest  # used for our unit...         pytest
# 1   [# imports\nimport pytest  # used for our unit...         pytest
# 2   [# imports\nimport pytest  # used for our unit...         pytest
# 3   [# imports\nimport pytest  # used for our unit...         pytest
# 4   [# imports\nimport pytest  # used for our unit...         pytest
# 5   [# imports\nimport pytest  # used for our unit...         pytest
# 6                                                None           None
# 7   [# imports\nimport pytest  # used for our unit...         pytest
# 8   [# imports\nimport pytest  # used for our unit...         pytest
# 9   [# imports\nimport pytest  # used for our unit...         pytest
# 10  [# imports\nimport pytest  # used for our unit...         pytest
# 11  [# imports\nimport pytest  # used for our unit...         pytest
# 12  [# imports\nimport pytest  # used for our unit...         pytest
# 13  [# imports\nimport pytest  # used for our unit...         pytest
# 14  [# imports\nimport pytest  # used for our unit...         pytest
# 15  [# imports\nimport pytest  # used for our unit...         pytest
# 16  [# imports\nimport pytest  # used for our unit...         pytest
# 17  [# imports\nimport pytest  # used for our unit...         pytest
# 18  [# imports\nimport pytest  # used for our unit...         pytest
# 19  [# imports\nimport pytest  # used for our unit...         pytest
# 20  [# imports\nimport pytest  # used for our unit...         pytest
# 21  [# imports\nimport pytest  # used for our unit...         pytest
# 22  [# imports\nimport pytest  # used for our unit...         pytest
# 23  [# imports\nimport pytest  # used for our unit...         pytest
# 24  [# imports\nimport pytest  # used for our unit...         pytest
# 25  [# imports\nimport pytest  # used for our unit...         pytest
# 26  [# imports\nimport pytest  # used for our unit...         pytest
# 27  [# imports\nimport pytest  # used for our unit...         pytest
# 28  [# imports\nimport pytest  # used for our unit...         pytest
# 29  [# imports\nimport pytest  # used for our unit...         pytest
# 30  [# imports\nimport pytest  # used for our unit...         pytest
# 31  [# imports\nimport pytest  # used for our unit...         pytest
# 32  [# imports\nimport numpy as np\nimport pytest ...         pytest
# 33  [# imports\nimport numpy as np\nimport pytest ...         pytest
# 34  [# imports\nimport sys\nfrom io import StringI...         pytest
# 35  [# imports\nimport sys\nfrom io import StringI...         pytest
# 36  [# imports\nimport pytest  # used for our unit...         pytest
# 37  [# imports\nimport pytest  # used for our unit...         pytest
# 38  [# imports\nimport pytest  # used for our unit...         pytest
# 39  [# imports\nimport pytest  # used for our unit...         pytest
# 40  [# imports\nimport pytest  # used for our unit...         pytest
#
#                          created_at aiservice_commit_id  \
# 0  2024-04-18 07:04:46.293923+00:00                None
# 1  2024-04-18 07:36:01.262393+00:00                None
# 2  2024-04-18 06:35:45.693971+00:00                None
# 3  2024-04-18 06:48:48.109749+00:00                None
# 4  2024-04-18 06:41:27.396525+00:00                None
# 5  2024-04-18 06:53:42.593377+00:00                None
# 6  2024-04-18 05:51:17.050279+00:00                None
# 7  2024-04-18 05:56:30.403736+00:00                None
# 8  2024-04-18 05:56:46.264470+00:00                None
# 9  2024-04-18 06:01:46.507944+00:00                None
# 10 2024-04-18 06:02:35.106678+00:00                None
# 11 2024-04-18 06:08:15.901816+00:00                None
# 12 2024-04-18 06:08:59.623131+00:00                None
# 13 2024-04-18 06:12:32.238456+00:00                None
# 14 2024-04-18 06:13:22.694382+00:00                None
# 15 2024-04-18 06:25:10.191869+00:00                None
# 16 2024-04-18 06:26:25.453153+00:00                None
# 17 2024-04-18 06:31:18.776319+00:00                None
# 18 2024-04-18 06:32:36.168592+00:00                None
# 19 2024-04-18 06:36:30.203958+00:00                None
# 20 2024-04-18 06:42:13.555734+00:00                None
# 21 2024-04-18 06:45:42.034069+00:00                None
# 22 2024-04-18 06:46:18.874782+00:00                None
# 23 2024-04-18 06:49:45.442555+00:00                None
# 24 2024-04-18 06:54:46.367119+00:00                None
# 25 2024-04-18 07:01:06.938556+00:00                None
# 26 2024-04-18 07:00:48.192315+00:00                None
# 27 2024-04-18 07:03:54.257947+00:00                None
# 28 2024-04-18 07:08:28.178195+00:00                None
# 29 2024-04-18 07:09:26.559622+00:00                None
# 30 2024-04-18 07:12:12.843008+00:00                None
# 31 2024-04-18 07:12:39.893205+00:00                None
# 32 2024-04-18 07:14:45.772244+00:00                None
# 33 2024-04-18 07:15:18.481698+00:00                None
# 34 2024-04-18 07:21:48.578802+00:00                None
# 35 2024-04-18 07:20:45.579750+00:00                None
# 36 2024-04-18 07:24:21.714743+00:00                None
# 37 2024-04-18 07:25:03.355030+00:00                None
# 38 2024-04-18 07:27:58.768033+00:00                None
# 39 2024-04-18 07:28:28.739280+00:00                None
# 40 2024-04-18 07:35:07.978001+00:00                None
#
#                                              metadata  \
# 0   {'test_timeout': 15, 'function_to_optimize': '...
# 1   {'test_timeout': 15, 'function_to_optimize': '...
# 2   {'test_timeout': 15, 'function_to_optimize': '...
# 3   {'test_timeout': 15, 'function_to_optimize': '...
# 4   {'test_timeout': 15, 'function_to_optimize': '...
# 5   {'test_timeout': 15, 'function_to_optimize': '...
# 6                                                None
# 7   {'test_timeout': 15, 'function_to_optimize': '...
# 8   {'test_timeout': 15, 'function_to_optimize': '...
# 9   {'test_timeout': 15, 'function_to_optimize': '...
# 10  {'test_timeout': 15, 'function_to_optimize': '...
# 11  {'test_timeout': 15, 'function_to_optimize': '...
# 12  {'test_timeout': 15, 'function_to_optimize': '...
# 13  {'test_timeout': 15, 'function_to_optimize': '...
# 14  {'test_timeout': 15, 'function_to_optimize': '...
# 15  {'test_timeout': 15, 'function_to_optimize': '...
# 16  {'test_timeout': 15, 'function_to_optimize': '...
# 17  {'test_timeout': 15, 'function_to_optimize': '...
# 18  {'test_timeout': 15, 'function_to_optimize': '...
# 19  {'test_timeout': 15, 'function_to_optimize': '...
# 20  {'test_timeout': 15, 'function_to_optimize': '...
# 21  {'test_timeout': 15, 'function_to_optimize': '...
# 22  {'test_timeout': 15, 'function_to_optimize': '...
# 23  {'test_timeout': 15, 'function_to_optimize': '...
# 24  {'test_timeout': 15, 'function_to_optimize': '...
# 25  {'test_timeout': 15, 'function_to_optimize': '...
# 26  {'test_timeout': 15, 'function_to_optimize': '...
# 27  {'test_timeout': 15, 'function_to_optimize': '...
# 28  {'test_timeout': 15, 'function_to_optimize': '...
# 29  {'test_timeout': 15, 'function_to_optimize': '...
# 30  {'test_timeout': 15, 'function_to_optimize': '...
# 31  {'test_timeout': 15, 'function_to_optimize': '...
# 32  {'test_timeout': 15, 'function_to_optimize': '...
# 33  {'test_timeout': 15, 'function_to_optimize': '...
# 34  {'test_timeout': 15, 'function_to_optimize': '...
# 35  {'test_timeout': 15, 'function_to_optimize': '...
# 36  {'test_timeout': 15, 'function_to_optimize': '...
# 37  {'test_timeout': 15, 'function_to_optimize': '...
# 38  {'test_timeout': 15, 'function_to_optimize': '...
# 39  {'test_timeout': 15, 'function_to_optimize': '...
# 40  {'test_timeout': 15, 'function_to_optimize': '...
#
#                                      explanations_raw         user_id
# 0   {'00db208c-b4df-4ac0-bf2c-4448f0c18897': 'The ...  github|2283165
# 1   {'426916b1-b122-44a7-aae3-c806b81887bd': 'The ...  github|2283165
# 2   {'0a631960-6c33-4de4-8d38-b31e888918c7': 'Here...  github|2283165
# 3   {'00f11305-5a9b-43cf-9d97-720b0a465d52': 'Your...  github|2283165
# 4   {'000711ac-1663-496b-837b-946040155a9c': 'Here...  github|2283165
# 5   {'04e41d16-15f6-4341-a976-f420ed3180a6': 'Here...  github|2283165
# 6   {'0ac2d5fc-7315-4ca1-af84-1a7d65cd93a6': 'In t...  github|2283165
# 7   {'21645d50-d094-47d5-9a16-9163d90ee040': 'The ...  github|2283165
# 8   {'3b74021f-df2a-43c1-a98c-c53c62c152b4': 'As t...  github|2283165
# 9   {'093d324b-76aa-4ad7-ab24-a4d10341d635': 'The ...  github|2283165
# 10  {'0ac7066f-a5cd-417c-8121-0614754e6b0a': 'The ...  github|2283165
# 11  {'4bf3dbec-6785-4cde-854b-f6331cba2a76': 'The ...  github|2283165
# 12  {'0e07a41c-8928-4d69-a0ba-33c8c2a29368': 'In t...  github|2283165
# 13  {'0717e2a6-a0ff-4e2b-950e-3e89cdf1a943': 'This...  github|2283165
# 14  {'2bdd685e-9076-4c06-af56-ed592ec2add9': 'The ...  github|2283165
# 15  {'0e834ccc-68e2-4ba2-929e-0362e7288322': 'The ...  github|2283165
# 16  {'0ca93779-ea4a-48a9-9437-600334e2b5bb': 'The ...  github|2283165
# 17  {'0c30fb73-0bac-475d-b78b-c6c099bc12ad': 'The ...  github|2283165
# 18  {'10eb6770-047a-4f60-b9ad-0d2688bab93b': 'I've...  github|2283165
# 19  {'0aafef05-c468-48e0-a795-986763cf6b7c': 'The ...  github|2283165
# 20  {'04068a66-840b-4ddb-a8c7-289be75266e4': 'The ...  github|2283165
# 21  {'226ed33b-0ca7-4e7c-8384-b8dc96b1b1f4': 'To o...  github|2283165
# 22  {'09301913-2eb2-40b2-8b51-49566e08ced7': 'The ...  github|2283165
# 23  {'0f86c075-6684-4c13-92cf-3166941c5c4c': 'The ...  github|2283165
# 24  {'0485cc8e-6ebd-4c81-9aed-61687af1c8ed': 'Revi...  github|2283165
# 25  {'1692b2dd-d865-466f-97d0-cd4859ea585d': 'In t...  github|2283165
# 26  {'1b3fcdb9-bdf2-419b-bf10-b4482dc75d8b': 'Your...  github|2283165
# 27  {'0257e7cf-b4a8-4771-bb02-6e4963fa9811': 'The ...  github|2283165
# 28  {'7ce6c3ed-4d5c-4a93-8f13-607d4fc92e03': 'The ...  github|2283165
# 29  {'349055c3-aec3-4872-8ad0-67965b7fcca8': 'In t...  github|2283165
# 30  {'3af102b2-e9a4-45d1-b6a4-da7d4cf77bf0': 'The ...  github|2283165
# 31  {'2442d889-079f-412a-b19c-e6b7c8cc77b2': 'The ...  github|2283165
# 32  {'06c81727-979e-4749-a61e-eeff019418b2': 'Your...  github|2283165
# 33  {'164e2619-d401-448d-8ef2-f17d6afac3b9': 'The ...  github|2283165
# 34  {'62e3b5fb-cf2b-4f76-8744-ccfd527ffd3f': 'I've...  github|2283165
# 35  {'45485c8f-f983-460a-9f33-2bb65c902530': 'The ...  github|2283165
# 36  {'06b34dc8-32bf-4e73-b344-4bc0962ba53e': 'The ...  github|2283165
# 37  {'114cd4d1-089f-482f-9cd1-994e06230713': 'I've...  github|2283165
# 38  {'248e3790-6c3e-4aa8-b33f-83f774e3aa1e': 'Your...  github|2283165
# 39  {'2db980c5-9316-418d-abcb-99587afe301c': 'I've...  github|2283165
# 40  {'083209b7-561e-4272-80c5-ecce1708dc67': 'Here...  github|2283165

# %%
calculate_performance(df)

# %%
def get_best_correct_speedup_ratio(speedup_ratios, is_correct):
    correct_speedup_ratios = {
        uuid: ratio for uuid, ratio in speedup_ratios.items() if is_correct.get(uuid)
    } if speedup_ratios is not None else {}

    if correct_speedup_ratios:
        return max(correct_speedup_ratios.values())
    return None

df["best_speedup_ratio"] = df.apply(
    lambda row: get_best_correct_speedup_ratio(
        row["speedup_ratio"], row["is_correct"]
    ) if row["speedup_ratio"] is not None else None,
    axis=1
)

# %%
df["best_speedup_ratio"]
# Out:
# 0             NaN
# 1             NaN
# 2        0.221124
# 3        1.810426
# 4        0.027525
# 5     1819.685393
# 6        0.072121
# 7        0.257811
# 8        0.136215
# 9     2321.426674
# 10    2334.771018
# 11      -0.020953
# 12      -0.014760
# 13            NaN
# 14            NaN
# 15       0.128617
# 16       0.128518
# 17     169.122981
# 18     163.927139
# 19       0.222118
# 20      -0.015617
# 21      -0.078898
# 22            NaN
# 23            NaN
# 24    1821.364426
# 25            NaN
# 26       0.049494
# 27       0.008551
# 28       0.312158
# 29       0.145024
# 30            NaN
# 31            NaN
# 32    1141.135658
# 33    1188.697713
# 34            NaN
# 35            NaN
# 36      -0.109723
# 37       0.107670
# 38       0.213890
# 39       0.200966
# 40            NaN
# Name: best_speedup_ratio, dtype: float64

# %% [markdown]
# df["best_speedup_ratio"]

# %%
perf_threshold=1.05

valid_candidates = df[
    df["is_correct"].dropna().apply(lambda x: x.get("overall"))
    & (df["best_speedup_ratio"].apply(lambda x: x is not None and x >= perf_threshold))
].dropna(subset=["best_speedup_ratio"])
valid_candidates
# Out:
# Empty DataFrame
# Columns: [trace_id, original_code, optimizations_raw, optimizations_post, explanations_post, speedup_ratio, original_runtime, optimized_runtime, is_correct, generated_test, test_framework, created_at, aiservice_commit_id, metadata, explanations_raw, user_id, best_speedup_ratio]
# Index: []

# %%
calculate_performance(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 calculate_performance(df)
#
# File ~/repos/tacit/codeflash/cli/codeflash/optimization/metrics_analysis.py:23, in calculate_performance(df, perf_threshold)
#      21 def calculate_performance(df, perf_threshold=1.0):
#      22     # Extract the best speedup ratio from the speedup_ratio dictionary, accounting for empty dictionaries
# ---> 23     df['best_speedup_ratio'] = df['speedup_ratio'].dropna().apply(lambda x: max(x.values()) if x else None)
#      25     # Filter out the rows where a valid candidate above the perf threshold was found
#      26     valid_candidates = df[df['is_correct'].apply(lambda x: x.get('overall')) & (df['best_speedup_ratio'] >= perf_threshold)].dropna(subset=['best_speedup_ratio'])
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/repos/tacit/codeflash/cli/codeflash/optimization/metrics_analysis.py:23, in calculate_performance.<locals>.<lambda>(x)
#      21 def calculate_performance(df, perf_threshold=1.0):
#      22     # Extract the best speedup ratio from the speedup_ratio dictionary, accounting for empty dictionaries
# ---> 23     df['best_speedup_ratio'] = df['speedup_ratio'].dropna().apply(lambda x: max(x.values()) if x else None)
#      25     # Filter out the rows where a valid candidate above the perf threshold was found
#      26     valid_candidates = df[df['is_correct'].apply(lambda x: x.get('overall')) & (df['best_speedup_ratio'] >= perf_threshold)].dropna(subset=['best_speedup_ratio'])
#
# TypeError: '>' not supported between instances of 'NoneType' and 'NoneType'

# %%
df['speedup_ratio']
# Out:
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3       {'4ae3816e-41f5-418a-b944-e864bb301d96': 0.028...
# 4                                                    None
#                               ...
# 3927                                                 None
# 3928                                                 None
# 3929                                                 None
# 3930                                                 None
# 3931                                                   {}
# Name: speedup_ratio, Length: 3932, dtype: object

# %%
import metrics_analysis
import importlib
importlib.reload(metrics_analysis)

calculate_performance(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       2 import importlib
#       3 importlib.reload(metrics_analysis)
# ----> 5 calculate_performance(df)
#
# File ~/repos/tacit/codeflash/cli/codeflash/optimization/metrics_analysis.py:26, in calculate_performance(df, perf_threshold)
#      23 df['best_speedup_ratio'] = df['speedup_ratio'].dropna().apply(lambda x: max(filter(None, x.values())) if x and any(x.values()) else None)
#      25 # Filter out the rows where a valid candidate above the perf threshold was found
# ---> 26 valid_candidates = df[df['is_correct'].apply(lambda x: x.get('overall')) & (df['best_speedup_ratio'].apply(lambda x: x is not None and x >= perf_threshold))].dropna(subset=['best_speedup_ratio'])
#      28 # Calculate the average speedup ratio of the PR
#      29 pr_gain = valid_candidates['best_speedup_ratio'].mean()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniforge3/envs/codeflash311/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File ~/repos/tacit/codeflash/cli/codeflash/optimization/metrics_analysis.py:26, in calculate_performance.<locals>.<lambda>(x)
#      23 df['best_speedup_ratio'] = df['speedup_ratio'].dropna().apply(lambda x: max(filter(None, x.values())) if x and any(x.values()) else None)
#      25 # Filter out the rows where a valid candidate above the perf threshold was found
# ---> 26 valid_candidates = df[df['is_correct'].apply(lambda x: x.get('overall')) & (df['best_speedup_ratio'].apply(lambda x: x is not None and x >= perf_threshold))].dropna(subset=['best_speedup_ratio'])
#      28 # Calculate the average speedup ratio of the PR
#      29 pr_gain = valid_candidates['best_speedup_ratio'].mean()
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
    df['best_speedup_ratio'] = df['speedup_ratio'].dropna().apply(lambda x: max(filter(None, x.values())) if x and any(x.values()) else None)

# %%
df['best_speedup_ratio']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3       0.028571
# 4            NaN
#           ...
# 3927         NaN
# 3928         NaN
# 3929         NaN
# 3930         NaN
# 3931         NaN
# Name: best_speedup_ratio, Length: 3932, dtype: float64
